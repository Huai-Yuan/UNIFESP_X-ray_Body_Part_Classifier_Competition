# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import tensorflow_addons as tfa
import matplotlib.pyplot as plt

from packages.DataAugmentation import dataAugmentation
from packages.DataProcessing import tfrecords
from packages.Model_CNN import get_model

plt.style.use('_mpl-gallery')
# Out:
# WARNING:tensorflow:Mixed precision compatibility check (mixed_float16): WARNING
# Your GPU may run slowly with dtype policy mixed_float16 because it does not have compute capability of at least 7.0. Your GPU:
#   NVIDIA GeForce GTX 1050, compute capability 6.1
# See https://developer.nvidia.com/cuda-gpus for a list of GPUs and their compute capabilities.
# If you will use compatible GPU(s) not attached to this host, e.g. by running a multi-worker model, you can ignore this warning. This message will only be logged once

# %%
N_SPLITS = 4
IMG_HEIGHT = 224
IMG_WIDTH = 224
BATCH_SIZE = 16
EPOCHS = 100
PATIENCE = 10
MAX_LR = 1e-4
MIN_LR = 1e-6

# %%
class_names = np.load("./output/class_names.npy", allow_pickle=True)
num_classes = len(class_names)

# %%
train_target = np.load("./output/train_target.npy", allow_pickle=True)
valid_target = np.load("./output/valid_target.npy", allow_pickle=True)

# %%
# Reading TFRecords
records = tfrecords(IMG_HEIGHT, IMG_WIDTH)
train_ds = records.get_dataset(f'./output/tfrecords_{IMG_HEIGHT}_{IMG_WIDTH}/train.tfrecords')
valid_ds = records.get_dataset(f'./output/tfrecords_{IMG_HEIGHT}_{IMG_WIDTH}/valid.tfrecords')

# %%
# Data augmentation
aug_train = dataAugmentation()
train_ds = train_ds.map(aug_train.augment_iamge, num_parallel_calls=tf.data.AUTOTUNE)

# %%
train_ds = train_ds.batch(BATCH_SIZE).prefetch(buffer_size=tf.data.AUTOTUNE).repeat()
valid_ds = valid_ds.batch(BATCH_SIZE).prefetch(buffer_size=tf.data.AUTOTUNE).repeat()

# %%
image_batch, label_batch = next(iter(train_ds))
plt.figure(figsize=(9, 6))
for i in range(6):
    ax = plt.subplot(2, 3, i + 1)
    plt.imshow(image_batch[i].numpy().reshape(IMG_HEIGHT, IMG_WIDTH), cmap='gray')
    label = label_batch[i].numpy()
    if label.sum() == 1:
        plt.title(class_names[np.argmax(label)])
    else:
        titles = ""
        for j in np.where(label == 1)[0]:
            titles = titles + class_names[j] + ", "
        plt.title(titles)
    plt.axis("off")
plt.show()

# %%
# Build Model

model = get_model(input_shape=(IMG_HEIGHT, IMG_WIDTH, 1), output_shape=num_classes)

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 1)]     0
#
#  rescaling (Rescaling)       (None, 224, 224, 1)       0
#
#  conv2d (Conv2D)             (None, 222, 222, 32)      320
#
#  max_pooling2d (MaxPooling2D  (None, 111, 111, 32)     0
#  )
#
#  batch_normalization (BatchN  (None, 111, 111, 32)     128
#  ormalization)
#
#  re_lu (ReLU)                (None, 111, 111, 32)      0
#
#  conv2d_1 (Conv2D)           (None, 109, 109, 64)      18496
#
#  max_pooling2d_1 (MaxPooling  (None, 54, 54, 64)       0
#  2D)
#
#  batch_normalization_1 (Batc  (None, 54, 54, 64)       256
#  hNormalization)
#
#  re_lu_1 (ReLU)              (None, 54, 54, 64)        0
#
#  conv2d_2 (Conv2D)           (None, 52, 52, 128)       73856
#
#  max_pooling2d_2 (MaxPooling  (None, 26, 26, 128)      0
#  2D)
#
#  batch_normalization_2 (Batc  (None, 26, 26, 128)      512
#  hNormalization)
#
#  re_lu_2 (ReLU)              (None, 26, 26, 128)       0
#
#  conv2d_3 (Conv2D)           (None, 24, 24, 256)       295168
#
#  max_pooling2d_3 (MaxPooling  (None, 12, 12, 256)      0
#  2D)
#
#  batch_normalization_3 (Batc  (None, 12, 12, 256)      1024
#  hNormalization)
#
#  re_lu_3 (ReLU)              (None, 12, 12, 256)       0
#
#  conv2d_4 (Conv2D)           (None, 10, 10, 512)       1180160
#
#  max_pooling2d_4 (MaxPooling  (None, 5, 5, 512)        0
#  2D)
#
#  batch_normalization_4 (Batc  (None, 5, 5, 512)        2048
#  hNormalization)
#
#  re_lu_4 (ReLU)              (None, 5, 5, 512)         0
#
#  global_average_pooling2d (G  (None, 512)              0
#  lobalAveragePooling2D)
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense (Dense)               (None, 22)                11286
#
# =================================================================
# Total params: 1,583,254
# Trainable params: 1,581,270
# Non-trainable params: 1,984
# _________________________________________________________________

# %%
train_counts = train_target.sum(axis=0)

weight = (1/train_counts) * (len(train_target)/num_classes)
class_weight = {i:weight[i] for i in range(len(weight))}

# %%
steps_per_epoch = len(train_target)//BATCH_SIZE
validation_steps = len(valid_target)//BATCH_SIZE

# %%
model.compile(optimizer=tfa.optimizers.RectifiedAdam(learning_rate=MAX_LR,
                                                     total_steps=EPOCHS*steps_per_epoch,
                                                     warmup_proportion=0.2,
                                                     min_lr=MIN_LR), 
              loss=tf.losses.CategoricalCrossentropy(),
              metrics=['accuracy'])

# %%
my_callbacks = tf.keras.callbacks.EarlyStopping(patience=PATIENCE, 
                                                monitor='val_loss', 
                                                restore_best_weights=True)

# %%
history = model.fit(train_ds, 
                    validation_data=valid_ds,
                    epochs=EPOCHS,
                    callbacks=[my_callbacks],
                    class_weight=class_weight,
                    steps_per_epoch=steps_per_epoch,
                    validation_steps=validation_steps)
# Out:
# Epoch 1/80
# 86/86 [==============================] - 18s 142ms/step - loss: 3.4306 - accuracy: 0.0189 - val_loss: 3.3058 - val_accuracy: 0.0417
# Epoch 2/80
# 86/86 [==============================] - 11s 123ms/step - loss: 3.3424 - accuracy: 0.0160 - val_loss: 3.3003 - val_accuracy: 0.0089
# Epoch 3/80
# 86/86 [==============================] - 12s 135ms/step - loss: 3.2655 - accuracy: 0.0175 - val_loss: 3.3282 - val_accuracy: 0.0089
# Epoch 4/80
# 86/86 [==============================] - 13s 147ms/step - loss: 3.1898 - accuracy: 0.0298 - val_loss: 3.3355 - val_accuracy: 0.0089
# Epoch 5/80
# 86/86 [==============================] - 11s 129ms/step - loss: 3.1592 - accuracy: 0.0349 - val_loss: 3.2827 - val_accuracy: 0.0089
# Epoch 6/80
# 86/86 [==============================] - 11s 130ms/step - loss: 3.0157 - accuracy: 0.0415 - val_loss: 3.2120 - val_accuracy: 0.0268
# Epoch 7/80
# 86/86 [==============================] - 11s 131ms/step - loss: 2.9832 - accuracy: 0.0531 - val_loss: 3.1293 - val_accuracy: 0.0268
# Epoch 8/80
# 86/86 [==============================] - 11s 131ms/step - loss: 2.9531 - accuracy: 0.0691 - val_loss: 3.0559 - val_accuracy: 0.1548
# Epoch 9/80
# 86/86 [==============================] - 11s 132ms/step - loss: 2.8555 - accuracy: 0.1229 - val_loss: 2.8764 - val_accuracy: 0.3393
# Epoch 10/80
# 86/86 [==============================] - 11s 133ms/step - loss: 2.7931 - accuracy: 0.1593 - val_loss: 2.7804 - val_accuracy: 0.3810
# Epoch 11/80
# 86/86 [==============================] - 11s 134ms/step - loss: 2.7908 - accuracy: 0.1629 - val_loss: 2.6557 - val_accuracy: 0.4435
# Epoch 12/80
# 86/86 [==============================] - 12s 138ms/step - loss: 2.6474 - accuracy: 0.2175 - val_loss: 2.5298 - val_accuracy: 0.4821
# Epoch 13/80
# 86/86 [==============================] - 12s 138ms/step - loss: 2.6204 - accuracy: 0.2589 - val_loss: 2.4714 - val_accuracy: 0.4435
# 86/86 [==============================] - 12s 144ms/step - loss: 1.2544 - accuracy: 0.6625 - val_loss: 1.0540 - val_accuracy: 0.7887
# Epoch 69/80
# 86/86 [==============================] - 12s 139ms/step - loss: 1.1959 - accuracy: 0.6938 - val_loss: 1.1543 - val_accuracy: 0.7381
# Epoch 70/80
# 86/86 [==============================] - 12s 141ms/step - loss: 1.2327 - accuracy: 0.6895 - val_loss: 1.0637 - val_accuracy: 0.7857
# Epoch 71/80
# 86/86 [==============================] - 12s 136ms/step - loss: 1.2167 - accuracy: 0.6735 - val_loss: 1.1025 - val_accuracy: 0.7619
# Epoch 72/80
# 86/86 [==============================] - 12s 138ms/step - loss: 1.2965 - accuracy: 0.6676 - val_loss: 1.0890 - val_accuracy: 0.7649
# Epoch 73/80
# 86/86 [==============================] - 12s 137ms/step - loss: 1.2393 - accuracy: 0.6727 - val_loss: 1.0856 - val_accuracy: 0.7857
# Epoch 74/80
# 86/86 [==============================] - 12s 138ms/step - loss: 1.2367 - accuracy: 0.6829 - val_loss: 1.0937 - val_accuracy: 0.7619
# Epoch 75/80
# 86/86 [==============================] - 12s 138ms/step - loss: 1.2042 - accuracy: 0.6989 - val_loss: 1.1609 - val_accuracy: 0.7530
# Epoch 76/80
# 86/86 [==============================] - 12s 139ms/step - loss: 1.2876 - accuracy: 0.6771 - val_loss: 1.0545 - val_accuracy: 0.8036
# Epoch 77/80
# 86/86 [==============================] - 12s 138ms/step - loss: 1.2581 - accuracy: 0.6836 - val_loss: 1.0410 - val_accuracy: 0.7976
# Epoch 78/80
# 86/86 [==============================] - 12s 137ms/step - loss: 1.1904 - accuracy: 0.6865 - val_loss: 1.0528 - val_accuracy: 0.7917
# Epoch 79/80
# 86/86 [==============================] - 12s 137ms/step - loss: 1.1228 - accuracy: 0.6982 - val_loss: 1.0519 - val_accuracy: 0.7857
# Epoch 80/80
# 86/86 [==============================] - 12s 138ms/step - loss: 1.1860 - accuracy: 0.6764 - val_loss: 1.0521 - val_accuracy: 0.7857

# %%
model.save(f'./output/models/model_CNN.h5')

# %%
# Validate the Model

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))
ax1.set_title('Accuracy')
ax1.plot(history.history['accuracy'], 'r', marker="o", label='accuracy')
ax1.plot(history.history['val_accuracy'], 'g', marker="x", label='val_accuracy')
ax1.legend()

ax2.set_title('Loss')
ax2.plot(history.history['loss'], 'r', marker="o", label='loss')
ax2.plot(history.history['val_loss'], 'g', marker="x", label='val_loss')
ax2.legend()

plt.show()

# %%
# Reading TFRecords
test_ds = records.get_test_dataset(f'./output/tfrecords_{IMG_HEIGHT}_{IMG_WIDTH}/test.tfrecords')

# %%
# Prediction
test_ds = test_ds.batch(BATCH_SIZE).prefetch(buffer_size=tf.data.AUTOTUNE)
pred = model.predict(test_ds)

# %%
# Submission
df_test = pd.read_csv("./input/sample_submission.csv")
df_test.Target = np.argmax(pred, axis=1)
df_test.to_csv("./output/submission.csv", index=False)
